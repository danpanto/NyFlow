# %% [markdown]
# # TODO

# %% [markdown]
# - Transformar columna `request_datetime` para obtener el tiempo de espera (junto con `on_scene_datetime`)
# -

# %% [markdown]
# # IMPORTS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import pyarrow.parquet as pq
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # CARGA DE DATOS

# %%
path = Path.cwd().parent / "data"

# %%
file_path = path / "hv_unified.parquet"

# pf = pq.ParquetFile(file_path)
# frames = []

# # Iteramos por trozos (batches) para no llenar la RAM
# for batch in pf.iter_batches(batch_size=100_000):
#     # Convertimos el trozo a Pandas
#     df_chunk = batch.to_pandas()

#     # Nos quedamos con el 5% aleatorio de este trozo (frac=0.05)
#     sample_chunk = df_chunk.sample(frac=0.05, random_state=42)
    
#     frames.append(sample_chunk)

# # Unimos las muestras
# df = pd.concat(frames)

df = pd.read_parquet(file_path, engine="pyarrow")

print(f"Tamaño de la muestra: {df.shape}")
df.head()
# Out:
# Tamaño de la muestra: (20818240, 25)
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2025-11-01 00:31:47 2025-11-01 00:36:39 2025-11-01 00:41:10
# 1 2025-11-01 00:10:11 2025-11-01 00:15:19 2025-11-01 00:17:14
# 2 2025-11-01 00:32:49 2025-11-01 00:38:38 2025-11-01 00:40:39
# 3 2025-11-01 00:09:56 2025-11-01 00:17:21 2025-11-01 00:18:34
# 4 2025-11-01 00:38:04 2025-11-01 00:41:53 2025-11-01 00:42:13
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 0 2025-11-01 00:59:52           148           170        3.48  ...
# 1 2025-11-01 00:47:29            72           228        6.64  ...
# 2 2025-11-01 01:04:02           137           143        3.51  ...
# 3 2025-11-01 00:36:06           112           140        4.15  ...
# 4 2025-11-01 01:15:07           141            82        5.51  ...
#
#    congestion_surcharge  airport_fee  tips  driver_pay  shared_request_flag  \
# 0                  2.75          0.0   0.0       46.10                    N
# 1                  0.00          0.0   0.0       37.43                    N
# 2                  2.75          0.0   0.0       39.16                    N
# 3                  2.75          0.0   0.0       34.70                    N
# 4                  2.75          0.0   0.0       30.78                    N
#
#    shared_match_flag  access_a_ride_flag  wav_request_flag  wav_match_flag  \
# 0                  N                   N                 N               N
# 1                  N                   N                 N               N
# 2                  N                   N                 N               N
# 3                  N                   N                 N               N
# 4                  N                   N                 N               N
#
#   cbd_congestion_fee
# 0                1.5
# 1                0.0
# 2                1.5
# 3                0.0
# 4                1.5
#
# [5 rows x 25 columns]

# %% [markdown]
# # ANÁLISIS

# %%
for row in df.iterrows():
    print(row)
    break
